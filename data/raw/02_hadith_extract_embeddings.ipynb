# %%
import json
import re
import math
import os
from nltk.corpus import stopwords
from pyarabic.araby import strip_diacritics
from lingua import Language, LanguageDetectorBuilder
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from tqdm import tqdm
import logging

# %%
import openai

class OpenAIManager:
    def __init__(self):
        """
        Initializes the OpenAIManager class with pre-defined languages, language detector,
        OpenAI model, and a prompt template for translation.
        """
        
        self.languages = [Language.ENGLISH, Language.ARABIC]
        self.lang_detector = LanguageDetectorBuilder.from_languages(*self.languages).build()
        self.openai_llm = OpenAI(temperature=0)
        self.prompt = PromptTemplate(
            input_variables=["query"],
            template="Translate the following arabic text into english : {query}"
        )
        
    def gpt3_embedding(self, content: str, engine: str = 'text-embedding-ada-002') -> list:
        """
        Generates an embedding for the input content using OpenAI GPT-3.

        Args:
            content (str): The input content for which the embedding is required.
            engine (str, optional): The engine to be used for generating the embedding. Defaults to 'text-embedding-ada-002'.

        Returns:
            list: The generated embedding as a list of floats.
        """
        try:
            response = openai.Embedding.create(input=content, engine=engine)
            vector = response['data'][0]['embedding']
            return vector
        except Exception as e:
            logging.error(f'Embedding failed. Error message: {e}')

    def extract_embedding(self, text: str) -> list:
        """
        Extracts the embedding for the given text using GPT-3.

        Args:
            text (str): The input text for which the embedding is required.

        Returns:
            list: The extracted embedding as a list of floats.
        """
        try:
            embedding = self.gpt3_embedding(text)
        except:
            while True:
                try:
                    if len(text) > 8191:
                        logging.warning('[OPENAI ERROR] Trying to get shorter input < 8191 for text...')
                        embedding = self.gpt3_embedding(text[:8191])
                    else:
                        embedding = self.gpt3_embedding(text)
                    break
                except Exception as e:
                    logging.error(f'Trying to get the embedding for text. Error message: {e}')
                    time.sleep(5)
        return embedding
    
    def translate(self, text: str) -> str:
        """
        Translates the input Arabic text to English using the OpenAI model.

        Args:
            text (str): The input Arabic text to be translated.

        Returns:
            str: The translated English text.
        """
        
        translated_text = self.openai_llm(self.prompt.format(query=text))
        return translated_text

# %%
os.environ["OPENAI_API_KEY"] = "Add you openai key"
openai_manager = OpenAIManager()

# %%
def clean_numbers(data):
    """
    Clean numerical values in a dictionary.
    
    Args:
        data (dict): A dictionary containing keys and values to be cleaned.
    
    Returns:
        dict: The cleaned dictionary with numerical values converted to integers.
    """
    for key, value in data.items():
        if isinstance(value, float) and not math.isnan(value):
            data[key] = int(value)
    return data

# %%
def preprocess_english_text(text):
    """
    Preprocess English text by converting to lowercase and removing non-alphanumeric characters.
    
    Args:
        text (str): The input text to preprocess.
    
    Returns:
        str: The preprocessed text.
    """
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r"[^\w\s]", "", text)
    return text

# %%
def clean_arabic_text(text):
    """
    Clean Arabic text by removing diacritics and non-alphanumeric characters.
    
    Args:
        text (str): The input text to clean.
    
    Returns:
        str: The cleaned text.
    """
    if isinstance(text, str):
        text = strip_diacritics(text)
        text = re.sub(r"[^\w\s]", "", text)
    return text

# %%
def clean_json_data(json_file):
    """
    Clean JSON data and extract GPT embeddings for each record.
    
    Args:
        json_file (str): The input JSON file containing the data to clean and process.
    """
    with open(json_file, "r", encoding="utf-8") as file:
        data = json.load(file)

    cleaned_data = []
    for record in tqdm(data):
        cleaned_record = clean_numbers(record)
        cleaned_record["English_Hadith"] = preprocess_english_text(cleaned_record["English_Hadith"])
        cleaned_record["English_Isnad"] = preprocess_english_text(cleaned_record["English_Isnad"])
        cleaned_record["English_Matn"] = preprocess_english_text(cleaned_record["English_Matn"])
        cleaned_record["Arabic_Hadith"] = clean_arabic_text(cleaned_record["Arabic_Hadith"])
        cleaned_record["Arabic_Isnad"] = clean_arabic_text(cleaned_record["Arabic_Isnad"])
        cleaned_record["Arabic_Matn"] = clean_arabic_text(cleaned_record["Arabic_Matn"])
        cleaned_record["Section_Arabic"] = clean_arabic_text(cleaned_record["Section_Arabic"])

        # Extract the embedding for the input text
        cleaned_record["embeddings"] = openai_manager.extract_embedding(cleaned_record["English_Matn"])

        cleaned_data.append(cleaned_record)

    with open("GPT_embeddings.json", "w") as output_file:
        json.dump(cleaned_data, output_file, ensure_ascii=False, indent=4)

# %%
def main():
    json_file = "hadith/termzi/termzi.json"
    clean_json_data(json_file)

# %%
if __name__ == "__main__":
    main()
# Out:
#   6%|██▍                                     | 253/4209 [01:00<22:11,  2.97it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▋                                     | 278/4209 [01:08<15:51,  4.13it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▊                                     | 296/4209 [01:12<14:12,  4.59it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▊                                     | 301/4209 [01:13<20:13,  3.22it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▉                                     | 305/4209 [01:14<16:31,  3.94it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▉                                     | 307/4209 [01:14<13:49,  4.70it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   7%|██▉                                     | 313/4209 [01:15<12:07,  5.36it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   8%|███                                     | 322/4209 [01:18<18:06,  3.58it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   8%|███                                     | 325/4209 [01:19<15:29,  4.18it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   8%|███▎                                    | 344/4209 [01:23<11:43,  5.49it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#   9%|███▊                                    | 397/4209 [01:33<14:20,  4.43it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  10%|███▉                                    | 408/4209 [01:36<16:25,  3.86it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  10%|███▉                                    | 417/4209 [01:39<15:20,  4.12it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  10%|████                                    | 421/4209 [01:40<15:58,  3.95it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  11%|████▎                                   | 453/4209 [01:46<15:40,  3.99it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  11%|████▍                                   | 471/4209 [01:51<14:31,  4.29it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  12%|████▊                                   | 506/4209 [02:00<14:28,  4.27it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  12%|████▊                                   | 510/4209 [02:00<11:23,  5.41it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  12%|████▉                                   | 519/4209 [02:02<10:39,  5.77it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  13%|█████▎                                  | 559/4209 [02:11<11:04,  5.49it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  13%|█████▎                                  | 562/4209 [02:11<10:42,  5.67it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  13%|█████▍                                  | 566/4209 [02:12<18:35,  3.26it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  14%|█████▍                                  | 570/4209 [02:13<17:56,  3.38it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#  14%|█████▌                                  | 579/4209 [02:15<14:27,  4.18it/s]ERROR:root:Embedding failed. Error message: We could not parse the JSON body of your request. (HINT: This likely means you aren't using your HTTP library correctly. The OpenAI API expects a JSON payload, but what was sent was not valid JSON. If you have trouble figuring out how to fix this, please send an email to support@openai.com and include any relevant code you'd like help with.)
#